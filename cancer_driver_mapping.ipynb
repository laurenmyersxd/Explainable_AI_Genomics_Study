# %%
import pandas as pd

# %% [markdown]
# ## Breast Cancer

# %%
bcancer_df = pd.read_csv('data/explainable_ai/Breast-AdenoCa_drivers.csv').drop("Unnamed: 0", axis = 1)
bcancer_df
# Out:
#                        feature    weight  abs_weight
# 0    snv_ms_driver_CBFB_Intron  0.336881    0.336881
# 1   snv_ms_driver_RUNX1_Intron  0.331920    0.331920
# 2    snv_ms_driver_ESR1_Intron  0.293999    0.293999
# 3   snv_ms_driver_BRIP1_Intron  0.292189    0.292189
# 4   snv_ms_driver_GATA3_Coding  0.286523    0.286523
# 5   snv_ms_driver_NCOR1_Intron  0.284829    0.284829
# 6  snv_ms_driver_MAP3K1_Intron  0.278004    0.278004
# 7             cna_total_len_Mb -0.240502    0.240502
# 8   snv_ms_driver_HERC2_Intron  0.240115    0.240115
# 9                       sv_TRA  0.239720    0.239720

# %%
snv_df = pd.read_csv('data/feature_eng/snv_features.csv').drop("Unnamed: 0", axis = 1)
snv_df[snv_df['snv_ms_driver_CBFB_Intron'] != 0.0]
# Out:
#                  sample_id  snv_total  snv_chr_1  snv_chr_10  snv_chr_11  \
# 0    sim100_Breast-AdenoCa       5590      470.0       215.0       256.0
# 72    sim18_Breast-AdenoCa       9266      817.0       406.0       425.0
# 88     sim1_Breast-AdenoCa       2749      201.0       126.0       123.0
# 112   sim22_Breast-AdenoCa       6471      535.0       291.0       282.0
# 120   sim23_Breast-AdenoCa       8302      719.0       385.0       421.0
# 136   sim25_Breast-AdenoCa       3880      338.0       189.0       167.0
# 168   sim29_Breast-AdenoCa       8580      740.0       414.0       380.0
# 224   sim35_Breast-AdenoCa       4901      429.0       205.0       243.0
# 240   sim37_Breast-AdenoCa       2823      227.0       130.0       116.0
# 256   sim39_Breast-AdenoCa       2351      172.0       123.0       104.0
# 264    sim3_Breast-AdenoCa       2714      237.0       137.0       117.0
# 272   sim40_Breast-AdenoCa       5682      488.0       254.0       222.0
# ...
